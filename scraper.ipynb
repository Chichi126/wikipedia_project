# %%
# !pip install bs4

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # Scraping data

# %%
uri = 'https://en.wikipedia.org/wiki/List_of_largest_universities_and_university_networks_by_enrollment'

response = requests.get(uri)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of largest universities and university networks by enrollment - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpr
# ...

# %%
soup = BeautifulSoup(response.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest universities and university networks by enrollment - Wikipedia</title>
# ...

# %%
table = soup.find('table', attrs ={'class':'wikitable sortable'})
table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Institution
# </th>
# <th>Location
# </th>
# <th>Continent
# </th>
# <th>Founded
# </th>
# <th>Affiliation
# </th>
# <th>Distance / In-Person<style data-mw-deduplicate="TemplateStyles:r1041539562">.mw-parser-output .citation{word-wrap:break-word}.mw-parser-output .citation:target{background-color:rgba(0,127,255,0.133)}</style><sup class="citation nobold" id="ref_distancea"><a href="#endnote_distancea">[a]</a></sup>
# </th>
# <th>Enrollment
# </th>
# <th class="unsortable">Ref
# </th></tr>
# <tr>
# <td>1
# </td>
# ...

# %%
trs = table.findAll('tr')
trs[0]
# Out:
# <tr>
# <th>Rank
# </th>
# <th>Institution
# </th>
# <th>Location
# </th>
# <th>Continent
# </th>
# <th>Founded
# </th>
# <th>Affiliation
# </th>
# <th>Distance / In-Person<style data-mw-deduplicate="TemplateStyles:r1041539562">.mw-parser-output .citation{word-wrap:break-word}.mw-parser-output .citation:target{background-color:rgba(0,127,255,0.133)}</style><sup class="citation nobold" id="ref_distancea"><a href="#endnote_distancea">[a]</a></sup>
# </th>
# <th>Enrollment
# </th>
# <th class="unsortable">Ref
# </th></tr>

# %%
trs[0].findAll('th')
column = []
for item in trs[0].findAll('th'):
    print(item.text.strip())
    column.append(item.text.strip())
# Out:
# Rank
# Institution
# Location
# Continent
# Founded
# Affiliation
# Distance / In-Person[a]
# Enrollment
# Ref

# %%
columns = list(map(lambda x:x.text.strip(),trs[0].findAll('th')))
columns
# Out:
# ['Rank',
#  'Institution',
#  'Location',
#  'Continent',
#  'Founded',
#  'Affiliation',
#  'Distance / In-Person[a]',
#  'Enrollment',
#  'Ref']

# %%
columns[-1] = 'Link'
columns
# Out:
# ['Rank',
#  'Institution',
#  'Location',
#  'Continent',
#  'Founded',
#  'Affiliation',
#  'Distance / In-Person[a]',
#  'Enrollment',
#  'Link']

# %%
rows = trs[1:]
rows
# Out:
# [<tr>
#  <td>1
#  </td>
#  <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a href="/wiki/India" title="India"><img alt="India" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/23px-Flag_of_India.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/35px-Flag_of_India.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/45px-Flag_of_India.svg.png 2x" width="23"/></a></span></span><a href="/wiki/Indira_Gandhi_National_Open_University" title="Indira Gandhi National Open University">Indira Gandhi National Open University</a>
#  </td>
#  <td><a href="/wiki/New_Delhi" title="New Delhi">New Delhi</a>, <a href="/wiki/India" title="India">India</a>
#  </td>
#  <td>Asia
#  </td>
#  <td>1985
#  </td>
#  <td>Public
#  </td>
#  <td>Distance/In-Person
#  </td>
#  <td>7,140,000+
#  </td>
# ...

# %%
rows[0].findAll(('td'))
# Out:
# [<td>1
#  </td>,
#  <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a href="/wiki/India" title="India"><img alt="India" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/23px-Flag_of_India.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/35px-Flag_of_India.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/45px-Flag_of_India.svg.png 2x" width="23"/></a></span></span><a href="/wiki/Indira_Gandhi_National_Open_University" title="Indira Gandhi National Open University">Indira Gandhi National Open University</a>
#  </td>,
#  <td><a href="/wiki/New_Delhi" title="New Delhi">New Delhi</a>, <a href="/wiki/India" title="India">India</a>
#  </td>,
#  <td>Asia
#  </td>,
#  <td>1985
#  </td>,
#  <td>Public
#  </td>,
#  <td>Distance/In-Person
#  </td>,
#  <td>7,140,000+
#  </td>,
# ...

# %%
list(map(lambda x: x.text.strip(),rows[0].findAll('td')))
# Out:
# ['1',
#  'Indira Gandhi National Open University',
#  'New Delhi, India',
#  'Asia',
#  '1985',
#  'Public',
#  'Distance/In-Person',
#  '7,140,000+',
#  '[1]\n[2][3]']

# %%
rows[0].findAll('td')[1].a.attrs['href']
# Out:
# '/wiki/India'

# %%
def extract_rows(tr):
    row_soup_list = tr.findAll('td')
    row = list(map(lambda x: x.text.strip(),row_soup_list))
    link = row_soup_list[1].a.attrs['href'].lstrip('/')
    row[-1] = f"https://en.wikipedia.org/{link}" if link else None
    return row


extract_rows(rows[0])
# Out:
# ['1',
#  'Indira Gandhi National Open University',
#  'New Delhi, India',
#  'Asia',
#  '1985',
#  'Public',
#  'Distance/In-Person',
#  '7,140,000+',
#  'https://en.wikipedia.org/wiki/India']

# %%
data = list(map(extract_rows,rows))
data
# Out:
# [['1',
#   'Indira Gandhi National Open University',
#   'New Delhi, India',
#   'Asia',
#   '1985',
#   'Public',
#   'Distance/In-Person',
#   '7,140,000+',
#   'https://en.wikipedia.org/wiki/India'],
#  ['2',
#   'National University, Bangladesh',
#   'Gazipur, Bangladesh',
#   'Asia',
#   '1992',
#   'Public',
#   'In-Person',
#   '3,425,832',
#   'https://en.wikipedia.org/wiki/Bangladesh'],
#  ['3',
#   'Anadolu University',
#   'Eskişehir, Turkey',
#   'Asia',
#   '1958',
#   'Public',
#   'Distance/In-Person',
#   '1,974,343',
#   'https://en.wikipedia.org/wiki/Turkey'],
#  ['4',
#   'California Community Colleges',
#   'California, United States',
#   'North America',
#   '1967',
#   'Public',
#   'In-Person',
#   '1,800,000',
#   'https://en.wikipedia.org/wiki/United_States'],
#  ['5',
#   'Islamic Azad University',
#   'Iran',
#   'Asia',
#   '1982',
#   'Private',
#   'In-Person',
#   '1,778,000',
#   'https://en.wikipedia.org/wiki/Iran'],
#  ['6',
# ...

# %%
file_name = 'universities.json'
with open(file_name, 'w', encoding='utf-8') as file:
    json.dump(data, file, indent=4)

# %%
df = pd.DataFrame(data = data, columns = columns)
df
# Out:
#    Rank                                        Institution  \
# 0     1             Indira Gandhi National Open University
# 1     2                    National University, Bangladesh
# 2     3                                 Anadolu University
# 3     4                      California Community Colleges
# 4     5                            Islamic Azad University
# ..  ...                                                ...
# 85   85                           Aix-Marseille University
# 86   86                                University of Hagen
# 87   87                             Université de Montréal
# 88   88                      University of the Philippines
# 89   89  Academic Center for Education, Culture and Res...
#
#                      Location      Continent Founded Affiliation  \
# 0            New Delhi, India           Asia    1985      Public
# 1         Gazipur, Bangladesh           Asia    1992      Public
# ...

# %%
df.to_csv('universities.csv', index=False)

# %%
import pandas as pd
import json
import csv
import psycopg2

df = pd.read_csv('universities.csv')

# %%
df
# Out:
#     Rank                                        Institution  \
# 0      1             Indira Gandhi National Open University
# 1      2                    National University, Bangladesh
# 2      3                                 Anadolu University
# 3      4                      California Community Colleges
# 4      5                            Islamic Azad University
# ..   ...                                                ...
# 85    85                           Aix-Marseille University
# 86    86                                University of Hagen
# 87    87                             Université de Montréal
# 88    88                      University of the Philippines
# 89    89  Academic Center for Education, Culture and Res...
#
#                      Location      Continent Founded Affiliation  \
# 0            New Delhi, India           Asia    1985      Public
# 1         Gazipur, Bangladesh           Asia    1992      Public
# ...

# %% [markdown]
# ## Transforming the Data

# %%
df.columns
# Out:
# Index(['Rank', 'Institution', 'Location', 'Continent', 'Founded',
#        'Affiliation', 'Distance / In-Person[a]', 'Enrollment', 'Link'],
#       dtype='object')

# %%
df.rename(columns={'Distance / In-Person[a]':'learning_mode'}, inplace=True)

# %%
df['learning_mode'].unique()
# Out:
# array(['Distance/In-Person', 'In-Person', 'Distance',
#        'In-Person/Distance', 'Distance / In-person',
#        'In-Person/ Distance'], dtype=object)

# %%
import numpy as np

df['learning_modes'] = np.where(
                                (df['learning_mode'].str.lower().str.contains('distance')) &
                                (df['learning_mode'].str.lower().str.contains('in-person')),
                                ['Distance/In-Person'],
                                df['learning_mode'])

# %%
df['learning_modes'].unique()
# Out:
# array(['Distance/In-Person', 'In-Person', 'Distance'], dtype=object)

# %%
df['YearFounded'] = df['Founded'].str.extract(r'(\d{4})')
df['YearFounded'] = df['YearFounded'].astype(int)

# %%
df['enrollment'] = df['Enrollment'].str.extract(r'([\d,]+)')
df['enrollment']=df['enrollment'].str.replace(',','', regex=False).astype(int)

# %%
df.drop(['Founded','Enrollment','learning_mode'], axis=1, inplace=True)

# %%
df.rename(columns={'learning_modes':'Learning_modes'}, inplace=True)
df.rename(columns={'enrollment':'Enrollment'}, inplace=True)

# %%
df
# Out:
#     Rank                                        Institution  \
# 0      1             Indira Gandhi National Open University
# 1      2                    National University, Bangladesh
# 2      3                                 Anadolu University
# 3      4                      California Community Colleges
# 4      5                            Islamic Azad University
# ..   ...                                                ...
# 85    85                           Aix-Marseille University
# 86    86                                University of Hagen
# 87    87                             Université de Montréal
# 88    88                      University of the Philippines
# 89    89  Academic Center for Education, Culture and Res...
#
#                      Location      Continent Affiliation  \
# 0            New Delhi, India           Asia      Public
# 1         Gazipur, Bangladesh           Asia      Public
# 2           Eskişehir, Turkey           Asia      Public
# ...

# %% [markdown]
# ## Normalizing the Dataframe

# %%
df.columns
# Out:
# Index(['Rank', 'Institution', 'Location', 'Continent', 'Affiliation', 'Link',
#        'Learning_modes', 'YearFounded', 'Enrollment'],
#       dtype='object')

# %% [markdown]
# ## Dimension Table
#
# ### dim-continent = 'continent', 'continent_id'
# ### dim-affiliation = 'Affiliation', 'affiliation_id'
# ### dim-learning_modes = 'Learning_modes', 'learning_mode_id'
# ### dim-location = 'Location', 'location_id'
# ### dim-institution = 'Institution', 'YearFounded', 'Link', 'institution_id'
#
#
# ## Fact
#
# ### fact-university = 'Rank', 'Enrollment', 'continent_id', 'affiliation_id', 'learning_mode_id', 'location_id', 'institution_id'

# %%
dim_continent = df[['Continent']].drop_duplicates().reset_index(drop=True)
dim_continent['continent_id']= dim_continent.index +1

df = df.merge(dim_continent[['Continent', 'continent_id']],
        on= ['Continent'],
        how='left'
             )
dim_continent
# Out:
#        Continent  continent_id
# 0           Asia             1
# 1  North America             2
# 2         Global             3
# 3         Africa             4
# 4         Europe             5
# 5  South America             6

# %%
dim_affiliation = df[['Affiliation']].drop_duplicates().reset_index(drop=True)
dim_affiliation['affiliation_id']= dim_affiliation.index +1

df = df.merge(dim_affiliation[['Affiliation', 'affiliation_id']],
        on= ['Affiliation'],
        how='left'
             )
dim_affiliation
# Out:
#   Affiliation  affiliation_id
# 0      Public               1
# 1     Private               2

# %%
dim_learning_modes = df[['Learning_modes']].drop_duplicates().reset_index(drop=True)
dim_learning_modes['learning_modes_id']= dim_learning_modes.index +1

df = df.merge(dim_learning_modes[['Learning_modes', 'learning_modes_id']],
        on= ['Learning_modes'],
        how='left'
             )
dim_learning_modes
# Out:
#        Learning_modes  learning_modes_id
# 0  Distance/In-Person                  1
# 1           In-Person                  2
# 2            Distance                  3

# %%
dim_location= df[['Location']].drop_duplicates().reset_index(drop=True)
dim_location['location_id']= dim_location.index +1

df = df.merge(dim_location[['Location', 'location_id']],
        on= ['Location'],
        how='left'
             )
dim_location
# Out:
#                      Location  location_id
# 0            New Delhi, India            1
# 1         Gazipur, Bangladesh            2
# 2           Eskişehir, Turkey            3
# 3   California, United States            4
# 4                        Iran            5
# ..                        ...          ...
# 69                Philippines           70
# 70              Madrid, Spain           71
# 71          Marseille, France           72
# 72             Hagen, Germany           73
# 73                     Canada           74
#
# [74 rows x 2 columns]

# %%
dim_institution= df[['Institution', 'YearFounded', 'Link']].drop_duplicates().reset_index(drop=True)
dim_institution['institution_id']= dim_institution.index +1

df = df.merge(dim_institution[['Institution', 'institution_id','YearFounded', 'Link']],
        on= ['Institution','YearFounded', 'Link'],
        how='left'
             )
dim_institution
# Out:
#                                           Institution  YearFounded  \
# 0              Indira Gandhi National Open University         1985
# 1                     National University, Bangladesh         1992
# 2                                  Anadolu University         1958
# 3                       California Community Colleges         1967
# 4                             Islamic Azad University         1982
# ..                                                ...          ...
# 85                           Aix-Marseille University         1409
# 86                                University of Hagen         1974
# 87                             Université de Montréal         1878
# 88                      University of the Philippines         1908
# 89  Academic Center for Education, Culture and Res...         1980
#
#                                            Link  institution_id
# 0           https://en.wikipedia.org/wiki/India               1
# ...

# %%
fact_univerisities = df[['Rank', 'Enrollment', 'continent_id', 'affiliation_id', 'learning_modes_id', 'location_id', 'institution_id']]

# %%
fact_univerisities
# Out:
#     Rank  Enrollment  continent_id  affiliation_id  learning_modes_id  \
# 0      1     7140000             1               1                  1
# 1      2     3425832             1               1                  2
# 2      3     1974343             1               1                  1
# 3      4     1800000             2               1                  2
# 4      5     1778000             1               2                  2
# ..   ...         ...           ...             ...                ...
# 85    85       80000             5               1                  2
# 86    86       69982             5               1                  3
# 87    87       67109             2               1                  1
# 88    88       64144             1               1                  1
# 89    89       60000             1               2                  2
#
#     location_id  institution_id
# 0             1               1
# 1             2               2
# ...

# %% [markdown]
# ## Write All the Tables as a CSV file

# %%
fact_univerisities.to_csv('fact_univerisities.csv', index=False)
dim_institution.to_csv('institution.csv', index=False)
dim_location.to_csv('location.csv', index=False)
dim_learning_modes.to_csv('learning_modes.csv', index=False)
dim_affiliation.to_csv('affiliation.csv', index=False)
dim_continent.to_csv('continent.csv', index=False)

# %% [markdown]
# ## Creating the Database Connection

# %%
# !pip install psycopg2-binary

# %%
import getpass

password = getpass.getpass()
print('password secured')
# Out:
#  ········
# password secured

# %%
import psycopg2

def get_connection():
    conn= psycopg2.connect(
        host='localhost',
        database='wiki_uni_db',
        user='postgres',
        password=password
    )
    return conn

# %% [markdown]
# ## Create the schema tables

# %%
def create_tables():
    conn = get_connection()
    cursor = conn.cursor()

    # Create schema
    create_schema = '''
        CREATE SCHEMA IF NOT EXISTS wiki;
    '''

    create_tables = '''
        DROP TABLE IF EXISTS wiki.fact_universities CASCADE;
        DROP TABLE IF EXISTS wiki.institution_dim CASCADE;
        DROP TABLE IF EXISTS wiki.affiliation_dim CASCADE;
        DROP TABLE IF EXISTS wiki.location_dim CASCADE;
        DROP TABLE IF EXISTS wiki.learning_modes_dim CASCADE;
        DROP TABLE IF EXISTS wiki.continents_dim CASCADE;

        CREATE TABLE wiki.institution_dim (
            Institution TEXT,
            YearFounded INT,
            Link TEXT,
            institution_id INT PRIMARY KEY
        );

        CREATE TABLE wiki.affiliation_dim (
            Affiliation TEXT,
            affiliation_id INT PRIMARY KEY
        );

        CREATE TABLE wiki.location_dim (
            Location TEXT,
            location_id INT PRIMARY KEY
        );

        CREATE TABLE wiki.learning_modes_dim (
            Learning_modes TEXT,
            learning_modes_id INT PRIMARY KEY
        );

        CREATE TABLE wiki.continents_dim (
            Continent TEXT,
            continent_id INT PRIMARY KEY
        );

        CREATE TABLE wiki.fact_universities (
            Rank INT,
            Enrollment INT,
            continent_id INT REFERENCES wiki.continents_dim(continent_id),
            affiliation_id INT REFERENCES wiki.affiliation_dim(affiliation_id),
            learning_modes_id INT REFERENCES wiki.learning_modes_dim(learning_modes_id),
            location_id INT REFERENCES wiki.location_dim(location_id),
            institution_id INT REFERENCES wiki.institution_dim(institution_id)
        );
    '''

    try:
        print('Creating schema...')
        cursor.execute(create_schema)

        print('Creating tables...')
        cursor.execute(create_tables)

        conn.commit()
        print('All tables created successfully.')

    except Exception as e:
        print(f'Error occurred during table creation: {e}')

    finally:
        cursor.close()
        conn.close()
        print('Database connection closed.')

# Run the function
create_tables()
# Out:
# Creating schema...
# Creating tables...
# All tables created successfully.
# Database connection closed.

# %% [markdown]
# ## Loading Tables into the Database

# %%
import csv
def load_data(csv_file_path, table_name, column_names):
    conn= get_connection()
    cursor= conn.cursor()
    with open(csv_file_path, 'r', encoding='utf-8') as file:
        reader= csv.reader(file)
        next(reader)
        for row in reader:
            placeholder =', '.join(['%s'] *len(row))
            query= f' INSERT INTO {table_name} ({", ".join(column_names)}) VALUES({placeholder});'

            cursor.execute(query, row)
    conn.commit()
    cursor.close()
    conn.close()
    print(f' dataset loaded successfully into the {table_name}')

# %%
load_data('affiliation.csv', 'wiki.affiliation_dim', ['Affiliation', 'affiliation_id'])
# Out:
#  dataset loaded successfully into the wiki.affiliation_dim

# %%
load_data('continent.csv','wiki.continents_dim', ['Continent', 'continent_id'])
# Out:
#  dataset loaded successfully into the wiki.continents_dim

# %%
load_data('institution.csv', 'wiki.institution_dim',['Institution', 'YearFounded','Link','institution_id'] )
# Out:
#  dataset loaded successfully into the wiki.institution_dim

# %%
load_data('learning_modes.csv', 'wiki.learning_modes_dim', ['Learning_modes', 'learning_modes_id'])
# Out:
#  dataset loaded successfully into the wiki.learning_modes_dim

# %%
load_data('location.csv', 'wiki.location_dim', ['Location', 'location_id'])
# Out:
#  dataset loaded successfully into the wiki.location_dim

# %%
load_data('fact_univerisities.csv', 'wiki.fact_universities', ['Rank','Enrollment','continent_id','affiliation_id','learning_modes_id',
                                                               'location_id', 'institution_id'])
# Out:
#  dataset loaded successfully into the wiki.fact_universities

# %%
import csv

def load_data(csv_file_path, table_name, column_names):
    conn= get_connection()
    cursor= conn.cursor()
    with open(csv_file_path, 'r', encoding='utf-8') as file:
        reader= csv.reader(file)
        next(reader)
        for row in reader:
            placeholder =', '.join(['%s'] *len(row))
            query= f' INSERT INTO {table_name} ({", ".join(column_names)}) VALUES({placeholder});'

            cursor.execute(query, row)
    conn.commit()
    cursor.close()
    conn.close()
    print(f' dataset loaded successfully into the {table_name}')

# %%
load_data('affiliation.csv', 'wiki.affiliation_dim', ['Affiliation', 'affiliation_id'])
# Out:
#  dataset loaded successfully into the wiki.affiliation_dim
