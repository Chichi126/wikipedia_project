# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://en.wikipedia.org/wiki/List_of_largest_universities')
response.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of largest universities - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-cont
# ...

# %%
soup = BeautifulSoup(response.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest universities - Wikipedia</title>
# ...

# %%
table = soup.find('table', attrs ={'class': 'sortable'})

# %%
table
# Out:
# <table class="sortable wikitable">
# <tbody><tr>
# <th>Country
# </th>
# <th>University
# </th>
# <th>Founded
# </th>
# <th>Type
# </th>
# <th>Enrollment
# </th>
# <th>Ref
# </th></tr>
# <tr>
# <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="500" data-file-width="700" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/36/Flag_of_Albania.svg/40px-Flag_of_Albania.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/36/Flag_of_Albania.svg/60px-Flag_of_Albania.svg.png 2x" width="21"/></span></span> </span><a href="/wiki/Albania" title="Albania">Albania</a>
# </td>
# <td><a href="/wiki/University_of_Tirana" title="University of Tirana">University of Tirana</a>
# </td>
# <td style="text-align: right;">1957
# </td>
# <td>Public
# </td>
# <td style="text-align: right;">35,000
# </td>
# <td>
# </td></tr>
# <tr>
# ...

# %%
trs = table.findAll(('tr'))
trs[0]
# Out:
# <tr>
# <th>Country
# </th>
# <th>University
# </th>
# <th>Founded
# </th>
# <th>Type
# </th>
# <th>Enrollment
# </th>
# <th>Ref
# </th></tr>

# %%
trs[0].findAll('th')
columns=[]
for item in trs[0].findAll('th'):
    print(item.text.strip())
    columns.append(item.text.strip())
# Out:
# Country
# University
# Founded
# Type
# Enrollment
# Ref

# %%
columns = list(map( lambda x: x.text.strip(), trs[0].findAll('th')))
columns
# Out:
# ['Country', 'University', 'Founded', 'Type', 'Enrollment', 'Ref']

# %%
rows = trs[1:]

# %%
rows[0].findAll('td')
# Out:
# [<td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="500" data-file-width="700" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/36/Flag_of_Albania.svg/40px-Flag_of_Albania.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/36/Flag_of_Albania.svg/60px-Flag_of_Albania.svg.png 2x" width="21"/></span></span> </span><a href="/wiki/Albania" title="Albania">Albania</a>
#  </td>,
#  <td><a href="/wiki/University_of_Tirana" title="University of Tirana">University of Tirana</a>
#  </td>,
#  <td style="text-align: right;">1957
#  </td>,
#  <td>Public
#  </td>,
#  <td style="text-align: right;">35,000
#  </td>,
#  <td>
#  </td>]

# %%
list(map(lambda x: x.text.strip(), rows[0].findAll('td')))
# Out:
# ['Albania', 'University of Tirana', '1957', 'Public', '35,000', '']

# %%
columns[-1] = 'Links'
columns
# Out:
# ['Country', 'University', 'Founded', 'Type', 'Enrollment', 'Links']

# %%
def extract_rows(tr):
    row_soup_list = tr.findAll('td')
    row = list(map(lambda x: x.text.strip(), row_soup_list))
    link =  row_soup_list[1].a.attrs['href'].lstrip('/')
    row[-1] = f' https://en.wikipedia.org/{link}' if link else ' '
    #print('link:', link)
    return row

# %%
extract_rows(rows[0])
# Out:
# link: wiki/University_of_Tirana
# ['Albania',
#  'University of Tirana',
#  '1957',
#  'Public',
#  '35,000',
#  ' https://en.wikipedia.org/wiki/University_of_Tirana']

# %%
rows[0].findAll('td')[1]
# Out:
# <td><a href="/wiki/University_of_Tirana" title="University of Tirana">University of Tirana</a>
# </td>

# %%
rows[0].findAll('td')[1].a.attrs['href']
# Out:
# '/wiki/University_of_Tirana'

# %%
data = list(map(extract_rows, rows))
data
# Out:
# [['Albania',
#   'University of Tirana',
#   '1957',
#   'Public',
#   '35,000',
#   ' https://en.wikipedia.org/wiki/University_of_Tirana'],
#  ['Algeria',
#   'Constantine University',
#   '1978',
#   'Public',
#   '85,000',
#   ' https://en.wikipedia.org/wiki/List_of_universities_in_Algeria'],
#  ['Angola',
#   'Agostinho Neto University',
#   '1962',
#   'Public',
#   '29,827',
#   ' https://en.wikipedia.org/wiki/Agostinho_Neto_University'],
#  ['Argentina',
#   'University of Buenos Aires',
#   '1821',
#   'Public',
#   '311,175',
#   ' https://en.wikipedia.org/wiki/University_of_Buenos_Aires'],
#  ['Australia',
#   'Monash University',
#   '1958',
#   'Public',
#   '73,807',
#   ' https://en.wikipedia.org/wiki/Monash_University'],
#  ['Austria',
#   'University of Vienna',
#   '1365',
#   'Public',
#   '91,000',
#   ' https://en.wikipedia.org/wiki/University_of_Vienna'],
#  ['Bangladesh',
#   'National University, Bangladesh',
#   '1992',
#   'Public',
#   '2,097,182',
# ...

# %%
df = pd.DataFrame(data= data, columns = columns)
df
# Out:
#            Country                        University Founded    Type  \
# 0          Albania              University of Tirana    1957  Public
# 1          Algeria            Constantine University    1978  Public
# 2           Angola         Agostinho Neto University    1962  Public
# 3        Argentina        University of Buenos Aires    1821  Public
# 4        Australia                 Monash University    1958  Public
# ..             ...                               ...     ...     ...
# 65          Turkey                Anadolu University    1958  Public
# 66  United Kingdom                   Open University    1969  Public
# 67   United States              Texas A&M University    1876  Public
# 68         Uruguay        University of the Republic    1949  Public
# 69       Venezuela  Universidad Central de Venezuela    1721  Public
#
#    Enrollment                                              Links
# 0      35,000   https://en.wikipedia.org/wiki/University_of_T...
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

uri = 'https://en.wikipedia.org/wiki/List_of_largest_universities_and_university_networks_by_enrollment'

my_respon = requests.get(uri)
my_respon.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of largest universities and university networks by enrollment - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpr
# ...

# %%
soup = BeautifulSoup(my_respon.content)

soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest universities and university networks by enrollment - Wikipedia</title>
# ...

# %%
table = soup.find('table', attrs ={'class': 'sortable'})

table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Institution
# </th>
# <th>Location
# </th>
# <th>Continent
# </th>
# <th>Founded
# </th>
# <th>Affiliation
# </th>
# <th>Distance / In-Person<style data-mw-deduplicate="TemplateStyles:r1041539562">.mw-parser-output .citation{word-wrap:break-word}.mw-parser-output .citation:target{background-color:rgba(0,127,255,0.133)}</style><sup class="citation nobold" id="ref_distancea"><a href="#endnote_distancea">[a]</a></sup>
# </th>
# <th>Enrollment
# </th>
# <th class="unsortable">Ref
# </th></tr>
# <tr>
# <td>1
# </td>
# ...

# %%
trs = table.findAll(('tr'))
trs[0]
# Out:
# <tr>
# <th>Rank
# </th>
# <th>Institution
# </th>
# <th>Location
# </th>
# <th>Continent
# </th>
# <th>Founded
# </th>
# <th>Affiliation
# </th>
# <th>Distance / In-Person<style data-mw-deduplicate="TemplateStyles:r1041539562">.mw-parser-output .citation{word-wrap:break-word}.mw-parser-output .citation:target{background-color:rgba(0,127,255,0.133)}</style><sup class="citation nobold" id="ref_distancea"><a href="#endnote_distancea">[a]</a></sup>
# </th>
# <th>Enrollment
# </th>
# <th class="unsortable">Ref
# </th></tr>

# %%
columns = list(map(lambda x: x.text.strip(), trs[0].findAll('th')))
columns [-1] = 'link'
columns
# Out:
# ['Rank',
#  'Institution',
#  'Location',
#  'Continent',
#  'Founded',
#  'Affiliation',
#  'Distance / In-Person[a]',
#  'Enrollment',
#  'link']

# %%
# to get the rolls

rows = trs[1:]
rows[0]
# Out:
# <tr>
# <td>1
# </td>
# <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a href="/wiki/India" title="India"><img alt="India" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/23px-Flag_of_India.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/35px-Flag_of_India.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/45px-Flag_of_India.svg.png 2x" width="23"/></a></span></span><a href="/wiki/Indira_Gandhi_National_Open_University" title="Indira Gandhi National Open University">Indira Gandhi National Open University</a>
# </td>
# <td><a href="/wiki/New_Delhi" title="New Delhi">New Delhi</a>, <a href="/wiki/India" title="India">India</a>
# </td>
# <td>Asia
# </td>
# <td>1985
# </td>
# <td>Public
# </td>
# <td>Distance/In-Person
# </td>
# <td>7,140,000+
# </td>
# ...

# %%
rows[0].findAll('td')
# Out:
# [<td>1
#  </td>,
#  <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a href="/wiki/India" title="India"><img alt="India" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/23px-Flag_of_India.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/35px-Flag_of_India.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/45px-Flag_of_India.svg.png 2x" width="23"/></a></span></span><a href="/wiki/Indira_Gandhi_National_Open_University" title="Indira Gandhi National Open University">Indira Gandhi National Open University</a>
#  </td>,
#  <td><a href="/wiki/New_Delhi" title="New Delhi">New Delhi</a>, <a href="/wiki/India" title="India">India</a>
#  </td>,
#  <td>Asia
#  </td>,
#  <td>1985
#  </td>,
#  <td>Public
#  </td>,
#  <td>Distance/In-Person
#  </td>,
#  <td>7,140,000+
#  </td>,
# ...

# %%
rows[0].findAll('td')[1].findAll('a')[1].attrs['href'].lstrip('/')
# Out:
# 'wiki/Indira_Gandhi_National_Open_University'

# %%
# def extract_rows(tr):
#     row_soup_list = tr.findAll('td')
#     row = list(map(lambda x: x.text.strip(), row_soup_list))
#     link =  row_soup_list[1].a.attrs['href'].lstrip('/')
#     row[-1] = f' https://en.wikipedia.org/{link}' if link else ' '
#     #print('link:', link)
#     return row

def extract_row(tr):
    row_soup_list = tr.findAll('td')
    row = list(map(lambda x: x.text.strip(), row_soup_list))
    link =  row_soup_list[1].findAll('a')[1].attrs['href'].lstrip('/')
    row[-1] = f' https://en.wikipedia.org/{link}' if link else ' '
    #print('link:', link)
    return row

# %%
extract_rows(rows[36])
# Out:
# ['36',
#  'City University of New York',
#  'New York, United States',
#  'North America',
#  '1961',
#  'Public',
#  'In-Person',
#  '243,000',
#  ' https://en.wikipedia.org/wiki/United_States']

# %%
data = list(map(extract_rows, rows))

# %%
data
# Out:
# [['1',
#   'Indira Gandhi National Open University',
#   'New Delhi, India',
#   'Asia',
#   '1985',
#   'Public',
#   'Distance/In-Person',
#   '7,140,000+',
#   ' https://en.wikipedia.org/wiki/India'],
#  ['2',
#   'National University, Bangladesh',
#   'Gazipur, Bangladesh',
#   'Asia',
#   '1992',
#   'Public',
#   'In-Person',
#   '3,425,832',
#   ' https://en.wikipedia.org/wiki/Bangladesh'],
#  ['3',
#   'Anadolu University',
#   'Eskişehir, Turkey',
#   'Asia',
#   '1958',
#   'Public',
#   'Distance/In-Person',
#   '1,974,343',
#   ' https://en.wikipedia.org/wiki/Turkey'],
#  ['4',
#   'California Community Colleges',
#   'California, United States',
#   'North America',
#   '1967',
#   'Public',
#   'In-Person',
#   '1,800,000',
#   ' https://en.wikipedia.org/wiki/United_States'],
#  ['5',
#   'Islamic Azad University',
#   'Iran',
#   'Asia',
#   '1982',
#   'Private',
#   'In-Person',
#   '1,778,000',
#   ' https://en.wikipedia.org/wiki/Iran'],
#  ['6',
# ...

# %%
df = pd.DataFrame(data = data, columns = columns)

# %%
df
# Out:
#    Rank                                        Institution  \
# 0     1             Indira Gandhi National Open University
# 1     2                    National University, Bangladesh
# 2     3                                 Anadolu University
# 3     4                      California Community Colleges
# 4     5                            Islamic Azad University
# ..  ...                                                ...
# 85   85                           Aix-Marseille University
# 86   86                                University of Hagen
# 87   87                             Université de Montréal
# 88   88                      University of the Philippines
# 89   89  Academic Center for Education, Culture and Res...
#
#                      Location      Continent Founded Affiliation  \
# 0            New Delhi, India           Asia    1985      Public
# 1         Gazipur, Bangladesh           Asia    1992      Public
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Institution', 'Location', 'Continent', 'Founded',
#        'Affiliation', 'Distance / In-Person[a]', 'Enrollment', 'link'],
#       dtype='object')

# %% [markdown]
# FactUniversityStats
# ├── Rank
# ├── Enrollment
# ├── institution_id (FK → dimInstitution)
# ├── location_id (FK → dimLocation)
# ├── affiliation_id (FK → dimAffiliation)
# └── delivery_mode_id (FK → dimDeliveryMode)
#
# dimInstitution
# ├── institution_id (PK)
# ├── Institution
# ├── Founded
# └── link
#
# dimLocation
# ├── location_id (PK)
# ├── Location
# └── Continent
#
# dimAffiliation
# ├── affiliation_id (PK)
# └── Affiliation
#
# dimDeliveryMode
# ├── delivery_mode_id (PK)
# └── Distance / In-Person
#
# dimcontinenet
# ├── continent_id (PK)
# └── continenet_name

# %%
df.rename(columns={'Distance / In-Person[a]': 'learning_mode'}, inplace=True)

df.rename(columns={'Continent': 'continenent_name'}, inplace=True)

# %%
df.rename(columns={'Affiliation': 'affiliate_Type'}, inplace=True)

# %%
df['founded_year'] = df['Founded'].str.extract(r'(\d{4})')

df['founded_year'] = df['founded_year'].astype(int)

# %%
df['clean_enrollment'] = df['Enrollment'].str.extract(r'([\d,]+)')  # extract number part
df['clean_enrollment'] = df['clean_enrollment'].str.replace(',', '', regex=False).astype(int)

# %%
df
# Out:
#    Rank                                        Institution  \
# 0     1             Indira Gandhi National Open University
# 1     2                    National University, Bangladesh
# 2     3                                 Anadolu University
# 3     4                      California Community Colleges
# 4     5                            Islamic Azad University
# ..  ...                                                ...
# 85   85                           Aix-Marseille University
# 86   86                                University of Hagen
# 87   87                             Université de Montréal
# 88   88                      University of the Philippines
# 89   89  Academic Center for Education, Culture and Res...
#
#                      Location continenent_name affiliate_Type  \
# 0            New Delhi, India             Asia         Public
# 1         Gazipur, Bangladesh             Asia         Public
# 2           Eskişehir, Turkey             Asia         Public
# ...

# %%
# Simple solution to standardize all combined formats to 'Distance/In-Person'
df['learning_modes'] = np.where(
    (df['learning_mode'].str.lower().str.contains('distance')) & 
    (df['learning_mode'].str.lower().str.contains('in-person')),
    'Distance/In-Person',
    df['learning_mode']
)

# %%
df.drop(['Founded', 'Enrollment', 'learning_mode'], axis=1, inplace=True)

# %%
## Normalizing the dataframe

# %%
dim_affiliate = df[['affiliate_Type']].drop_duplicates().reset_index(drop=True)
dim_affiliate['affiliate_id']= dim_affiliate.index +1

df = df.merge(dim_affiliate[['affiliate_Type', 'affiliate_id']],
        on= ['affiliate_Type'],
        how='left'
             )

dim_affiliate
# Out:
#   affiliate_Type  affiliate_id
# 0         Public             1
# 1        Private             2

# %%
learningMode = df[['learning_modes']].drop_duplicates().reset_index(drop=True)
learningMode['learning_mode_id']= learningMode.index +1

df = df.merge(learningMode[['learning_modes', 'learning_mode_id']],
        on= ['learning_modes'],
        how='left'
             )
learningMode
# Out:
#        learning_modes  learning_mode_id
# 0  Distance/In-Person                 1
# 1           In-Person                 2
# 2            Distance                 3

# %%
continent = df[['continenent_name']].drop_duplicates().reset_index(drop=True)
continent['continent_id']= continent.index +1

df = df.merge(continent[['continenent_name', 'continent_id']],
        on= ['continenent_name'],
        how='left'
             )
continent
# Out:
#   continenent_name  continent_id
# 0             Asia             1
# 1    North America             2
# 2           Global             3
# 3           Africa             4
# 4           Europe             5
# 5    South America             6

# %%
location = df[['Location']].drop_duplicates().reset_index(drop=True)
location['location_id']= location.index +1

df = df.merge(location[['Location', 'location_id']],
        on= ['Location'],
        how='left'
             )
location
# Out:
#                      Location  location_id
# 0            New Delhi, India            1
# 1         Gazipur, Bangladesh            2
# 2           Eskişehir, Turkey            3
# 3   California, United States            4
# 4                        Iran            5
# ..                        ...          ...
# 69                Philippines           70
# 70              Madrid, Spain           71
# 71          Marseille, France           72
# 72             Hagen, Germany           73
# 73                     Canada           74
#
# [74 rows x 2 columns]

# %%
institution = df[['Institution', 'founded_year','link' ]].drop_duplicates().reset_index(drop=True)
institution['institution_id']= institution.index +1

df = df.merge(institution[['Institution', 'founded_year','link', 'institution_id' ]],
        on= ['Institution', 'founded_year','link' ],
        how='left'
             )
institution
# Out:
#                                           Institution  founded_year  \
# 0              Indira Gandhi National Open University          1985
# 1                     National University, Bangladesh          1992
# 2                                  Anadolu University          1958
# 3                       California Community Colleges          1967
# 4                             Islamic Azad University          1982
# ..                                                ...           ...
# 85                           Aix-Marseille University          1409
# 86                                University of Hagen          1974
# 87                             Université de Montréal          1878
# 88                      University of the Philippines          1908
# 89  Academic Center for Education, Culture and Res...          1980
#
#                                             link  institution_id
# 0            https://en.wikipedia.org/wiki/India               1
# ...

# %%
FactUniversityStats
├── Rank
├── Enrollment
├── institution_id (FK → dimInstitution)
├── location_id (FK → dimLocation)
├── affiliation_id (FK → dimAffiliation)
└── delivery_mode_id (FK → dimDeliveryMode)

# %%
factUniversityStats = df[['Rank', 'clean_enrollment', 'institution_id', 'continent_id', 'location_id', 'affiliate_id', 'learning_mode_id']]
factUniversityStats
# Out:
#    Rank  clean_enrollment  institution_id  continent_id  location_id  \
# 0     1           7140000               1             1            1
# 1     2           3425832               2             1            2
# 2     3           1974343               3             1            3
# 3     4           1800000               4             2            4
# 4     5           1778000               5             1            5
# ..  ...               ...             ...           ...          ...
# 85   85             80000              86             5           72
# 86   86             69982              87             5           73
# 87   87             67109              88             2           74
# 88   88             64144              89             1           70
# 89   89             60000              90             1            5
#
#     affiliate_id  learning_mode_id
# 0              1                 1
# 1              1                 2
# ...

# %%
## creating table

# %%
def create_tables():
    conn = get_connection()
    cursor = conn.cursor()

    # Create schema
    create_schema = '''
        CREATE SCHEMA IF NOT EXISTS zapco;
    '''

    # Drop existing tables and create new ones
    create_tables = '''
        DROP TABLE IF EXISTS zapco.date_dim CASCADE;
        DROP TABLE IF EXISTS zapco.location_dim CASCADE;
        DROP TABLE IF EXISTS zapco.owner_dim CASCADE;
        DROP TABLE IF EXISTS zapco.property_dim CASCADE;
        DROP TABLE IF EXISTS zapco.property_fact CASCADE;

        CREATE TABLE zapco.date_dim (
            year INT,
            month_name TEXT,
            quarter INT,
            lastSaleDate DATE,
            date_id INT PRIMARY KEY
        );

        CREATE TABLE zapco.location_dim (
            addressLine1 TEXT,
            city TEXT,
            state TEXT,
            zipCode INT,
            county TEXT,
            latitude FLOAT,
            longitude FLOAT,
            zoning TEXT,
            subdivision TEXT,
            location_id INT PRIMARY KEY
        );

        CREATE TABLE zapco.owner_dim (
            owners_name TEXT,
            owner_type TEXT,
            ownerOccupied FLOAT, 
            owner_id INT PRIMARY KEY
        );

        CREATE TABLE zapco.property_dim (
            propertyType TEXT,
            features TEXT,
            bathrooms FLOAT,
            bedrooms FLOAT,
            squareFootage FLOAT,
            lotSize FLOAT,
            yearBuilt FLOAT,
            assessorID TEXT,
            legalDescription TEXT,
            property_id INT PRIMARY KEY
        );
        CREATE TABLE zapco.property_fact(
            fact_id SERIAL PRIMARY KEY,
            date_id INT REFERENCES zapco.date_dim(date_id),
            location_id INT REFERENCES zapco.location_dim(location_id),
            owner_id INT REFERENCES zapco.owner_dim(owner_id),
            property_id INT REFERENCES zapco.property_dim(property_id),
            taxAssessments_2022_value NUMERIC,
            taxAssessments_2023_value NUMERIC,
            propertyTaxes_2022_total NUMERIC,
            propertyTaxes_2023_total NUMERIC,
            lastSalePrice NUMERIC,
            created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
            );
            
    
    '''
    
    try:
        print("Creating Schema....")
        cursor.execute(create_schema)
        
        print("Creating tables...")
        cursor.execute(create_tables)

        conn.commit()
        print("All tables created successfully")
              
    except Exception as e:
        print(f"Error occurred during the table creation: {e}")
    
    finally:
        cursor.close()
        conn.close()
        print("Database connection closed")

create_tables()

# %%
def load_data(csv_file_path, table_name, column_names):
    conn= get_connection()
    cursor= conn.cursor()
    with open(csv_file_path, 'r', encoding='utf-8') as file:
        reader= csv.reader(file)
        next(reader)
        for row in reader:
            placeholder =', '.join(['%s'] *len(row))
            query= f' INSERT INTO {table_name} ({", ".join(column_names)}) VALUES({placeholder});'

            cursor.execute(query, row)
    conn.commit()
    cursor.close()
    conn.close()
    print(f' dataset loaded successfully into the {table_name}')
